# %% [markdown]
# # Ejercicio de Aprendizaje no Supervisado
#
# Vamos a practicar todo lo que hemos visto en el tema de Aprendizaje no Supervisado. Para ello vamos a utilizar un conjunto de datos de características organolépticas de los vinos tintos de una determinada región portuguesa. El dataset viene de [Kaggle](https://www.kaggle.com/piyushgoyal443/red-wine-dataset) y cuenta con 13 variables, aunque tendremos que obviar 2 de ellas (una es simplemente un índice y otra es la nota que obtiene un vino en el rango $[0,10]$, la cual utilizaremos como _ground truth_.
#
# Hay que aplicar todo el proceso que hemos visto en clase:
#
# - pre-procesado
# - selección del modelo
# - optimización de hiper-parámetros
# - evaluación del modelo seleccionado con métricas de calidad tanto si admiten _ground truth_ como si no

# %%
import pandas as pd

# %%
raw = pd.read_csv('https://drive.upm.es/index.php/s/WTQ17khTvwIXVaT/download')

# %%
raw
